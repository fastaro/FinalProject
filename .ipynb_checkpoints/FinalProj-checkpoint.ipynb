# %%
import numpy as np
import pandas as pd
import soundfile
import IPython
import librosa
import librosa.display
from python_speech_features import mfcc, logfbank
from scipy.io import wavfile
import os
import matplotlib.pyplot as plt
from keras.layers import Conv2D, MaxPool2D, Flatten, LSTM
from keras.layers import Dropout, Dense, TimeDistributed
from keras.models import Sequential
from keras.utils import to_categorical
from keras.callbacks import ModelCheckpoint
from sklearn.utils.class_weight import compute_class_weight
from keras.optimizers import Adam
from keras.utils import np_utils
from sklearn import metrics

# %%
def file_lister(name):
    listy = []
    path = name
    try:
        files = os.listdir(path)
        for file in files:
            listy.append(file)
    except:
        None
    return listy

columns = ['fname', 'category']
df = pd.DataFrame(columns=columns)
categories = file_lister('Main Audio Folder')
for x in categories:
    for root, dirs, files in os.walk('Main Audio Folder/'+x):
        for file in files:
            if file.endswith('.wav'):
                df = df.append({'fname' : file , 'category' : x} , ignore_index=True)
                data, samplerate = soundfile.read('Main Audio Folder/'+x+'/'+file)
                soundfile.write('DrumSamples/'+file, data, samplerate, subtype='PCM_16')

df.to_csv('Drum Categories.csv')
df.head()
# Out:
#                        fname category
# 0  S_S95_01_BdH1_-_ (17).wav     Kick
# 1          KICK - BLOCKA.wav     Kick
# 2    Do What U Do Kick 1.wav     Kick
# 3         CANTHEM Kick 2.wav     Kick
# 4      KICK - TEEN SPIRT.wav     Kick

# %%
for x in np.unique(df.category):
    print(x+': '+str(len(df[df.category==x])))
# Out:
# 808: 283
# Clap: 385
# Closed Hat: 414
# Kick: 885
# Open Hat: 230
# Snare: 866
# Tom: 296
# Vox: 1120

# %%
from wavfilehelper import WavFileHelper
wavfilehelper = WavFileHelper()

metadata = pd.read_csv('Drum Categories.csv')

audiodata = []


for files in os.walk('DrumSamples/'):
        for file in files:
            for x in file:
                if x.endswith('.wav'):
                    data = wavfilehelper.read_file_properties('DrumSamples/'+x)
                    audiodata.append(data)

            
            

audiodf = pd.DataFrame(audiodata, columns=['num_channels','sample_rate','bit_depth'])
audiodf.head()
# Out:
#    num_channels  sample_rate  bit_depth
# 0             2        44100         16
# 1             2        48000         16
# 2             2        44100         16
# 3             2        44100         16
# 4             2        44100         16

# %% [markdown]
# # Mel-frequency cepstral coefficients (MFCCs)
# The MFCCs takes the frequency copenents (spectrogram) and put it into the mel-space which approximates how humans hear better than linear spaced frequencies.
#
# To get the MFFC of a signal you must
# 1. Compute the Fast Fourier Transform of the signal
# 2. Apply a Mel-space filter bank to the spectrum
# 3. Compute a discrete cosine transform of the log filter-bank energies

# %%
def extract_features(file_name):
    '''takes the mfccs of the wave file'''

    sample_rate, audio = wavfile.read(file_name) 
    step = step = int(sample_rate/100)
    #sample = audio[0:10]
    rand_index = np.random.randint(0,step)
    sample = audio[rand_index:rand_index+step]
    X_sample = mfcc(sample, sample_rate,
                       numcep=13, nfilt = 26, nfft = 2048)
#         mfccs = librosa.feature.mfcc(y=sample, sr=sample_rate, n_mfcc=256)
#         mfccsscaled = np.mean(mfccs.T,axis=0)
        

     
    return X_sample

# %%
extract_features('DrumSamples/JUICE Snare 4.wav').shape
# Out:
# (1, 13)

# %%
def extract_features(file_name):
    '''takes the averaged mfccs of the wave file'''
    try:
        audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast') 
        audiot = librosa.effects.trim(audio)[0]
        mfccs = librosa.feature.mfcc(y=audiot, sr=sample_rate, n_mfcc=256)
        mfccsscaled = np.mean(mfccs.T,axis=0)
        
    except Exception as e:
        print("Error encountered while parsing file: ", file)
        return None 
     
    return mfccsscaled

# %%
def mfccs_plot(file_name, title='Mel-frequency spectrogram'):
   
    try:
        audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast') 
        audiot = librosa.effects.trim(audio)[0]
        S = librosa.feature.melspectrogram(y=audiot, sr=sample_rate)
        plt.figure(figsize=(10, 4))
        S_dB = librosa.power_to_db(S, ref=np.max)
        librosa.display.specshow(S_dB, x_axis='time',
                                 y_axis='mel', 
                                 fmax=8000)
        plt.colorbar(format='%+2.0f dB')
        plt.title(title)
        plt.tight_layout()
        plt.show()
        
    except Exception as e:
        print("Error encountered while parsing file: ", file)
        return None 
     
    return None

# %%
def mfccs_plot(df, title='Mel-frequency spectrogram'):
    i = 1
    try:
        for x in np.unique(df.category):
            files = df[df.category==x].fname
            file = sample(list(files),1)[0]
            audio, sample_rate = librosa.load(file, res_type='kaiser_fast') 
            #audiot = librosa.effects.trim(audio)[0]
            S = librosa.feature.melspectrogram(y=audio, sr=sample_rate)
            plt.figure(figsize=(10, 4))
            S_dB = librosa.power_to_db(S, ref=np.max)
            librosa.display.specshow(S_dB, x_axis='time',
                                     y_axis='mel', 
                                     fmax=8000)


            plt.subplot(4, 2, i)
            i = i +1
            plt.colorbar(format='%+2.0f dB')
            plt.title(file)
            plt.tight_layout()
        
        
    except Exception as e:
        print("Error encountered while parsing file: ", file)
        return None 
    plt.show()
    return None

# %%
mfccs_plot(df)
# Out:
# Error encountered while parsing file:  808 (18).wav

# %%
fig, axes = plt.subplots(nrows=2, ncols=4, sharex=False,
                             sharey=True, figsize=(20,5))
    fig.suptitle('Mel Frequency Cepstrum Coefficients', size=16)

# %%
df.head()
# Out:
#                        fname category
# 0  S_S95_01_BdH1_-_ (17).wav     Kick
# 1          KICK - BLOCKA.wav     Kick
# 2    Do What U Do Kick 1.wav     Kick
# 3         CANTHEM Kick 2.wav     Kick
# 4      KICK - TEEN SPIRT.wav     Kick

# %%
from random import sample
for x in np.unique(df.category):
    files = df[df.category==x].fname
    file = sample(list(files),1)[0]
    mfccs_plot('DrumSamples/'+file,title=x)

# %%
min_length('DrumSamples/808_Tradewinds_A.wav')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-78-98be4eaf2ce0> in <module>
# ----> 1 min_length('DrumSamples/808_Tradewinds_A.wav')
#
# NameError: name 'min_length' is not defined

# %%
file
# Out:
# '808_Tradewinds_A.wav'

# %%
mfccs_plot('DrumSamples/JUICE Snare 4.wav')

# %%
extract_features('DrumSamples/JUICE Snare 4.wav')
# Out:
# array([[  2.39600854, -19.31497829,  -0.5362176 ,  13.52780419,
#         -14.51366394,  -3.88987459, -13.95435596,   2.75470455,
#         -18.48111731,  -0.80688823, -11.04478463, -13.29325779,
#         -25.2223099 ],
#        [  2.80830172, -24.13392362,   1.88567629,  18.68645773,
#          -8.78350612,  -2.11376108, -11.77301644,  -0.73104364,
#         -21.83868582,   2.22300222,  -7.80351786, -12.49866035,
#         -28.05736898],
#        [  2.81019263, -28.64839422,  -2.16337624,  21.67994766,
#          -5.16426464,   4.93044546,  -3.33302834,   3.30782509,
#         -18.0517426 ,   4.22141524,  -7.25745814,  -6.17306376,
#         -21.02182894],
#        [  2.32891996, -30.48846214,  -1.44675483,  23.90185862,
#          -5.72967532,   1.22110431,  -9.38053077,   0.81419748,
#         -15.09643879,   3.90775716, -17.08385918,  -8.20929903,
#         -19.44656961],
#        [  1.57998082, -31.40876486,  -1.98908938,  23.88163132,
#          -5.76263618,  10.30448646,   6.19848383,  13.91375945,
#          -4.55044606,  11.52110751, -12.28693272, -13.40260466,
#         -24.51053463],
#        [ -0.07702929, -32.34532262,  -4.43798666,  17.60746318,
#          -9.79031157,  -1.75207065,  -4.84826517,   2.97201202,
#         -14.27428993,   1.40122707, -18.95861459, -21.70501269,
#         -13.0688711 ]])

# %%
extract_features('DrumSamples/808_Tradewinds_A.wav').shape
# Out:
# (6, 13)

# %%
plt.plot((extract_features('DrumSamples/808_Tradewinds_A.wav')))
plt.show()

# %%
fulldatasetpath = 'DrumSamples/'

X = []

features = []



                    
                    
for files in os.walk('DrumSamples/'):
    for file in files:
        for x in file:
            if x.endswith('.wav'):
                class_label = list(df.loc[df['fname'] == x].category)[0]
                data = extract_features('DrumSamples/'+x)
                print(data.shape)
                X.append(data)
                features.append([data, class_label])

featuresdf = pd.DataFrame(features, columns=['feature','class_label'])
X = np.array(X)
X = X.reshape(X.shape[0], X.shape[1], X.shape[2],1)
print('Finished feature extraction from ', len(featuresdf), ' files')
# Out:
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# W1121 15:45:50.754555 4672710080 sigproc.py:82] frame length (2400) is greater than FFT size (2048), frame will be truncated. Increase NFFT to avoid.
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# W1121 15:45:58.204506 4672710080 sigproc.py:82] frame length (2400) is greater than FFT size (2048), frame will be truncated. Increase NFFT to avoid.
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# W1121 15:46:01.134117 4672710080 sigproc.py:82] frame length (2400) is greater than FFT size (2048), frame will be truncated. Increase NFFT to avoid.
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# W1121 15:46:01.921682 4672710080 sigproc.py:82] frame length (2400) is greater than FFT size (2048), frame will be truncated. Increase NFFT to avoid.
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# W1121 15:46:02.748499 4672710080 sigproc.py:82] frame length (2400) is greater than FFT size (2048), frame will be truncated. Increase NFFT to avoid.
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# W1121 15:46:02.826747 4672710080 sigproc.py:82] frame length (2400) is greater than FFT size (2048), frame will be truncated. Increase NFFT to avoid.
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# W1121 15:46:05.687505 4672710080 sigproc.py:82] frame length (2400) is greater than FFT size (2048), frame will be truncated. Increase NFFT to avoid.
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# (1, 13)
# Finished feature extraction from  4478  files

# %%
X.shape
# Out:
# (4478, 1, 13, 1)

# %%
data = extract_features('DrumSamples/Chinese Clap 2.wav')

# %%
featuresdf['feature'].iloc[200].shape
# Out:
# (6, 13)

# %%
#input_shape = (128, 1, 1)

def get_conv_model():
    model = Sequential()
    model.add(Conv2D(8,(3,3), activation='relu', strides=(1,1),
                    padding = 'same', input_shape=input_shape))
    model.add(Dropout(0.1))
    model.add(Conv2D(16,(3,3), activation='relu', strides=(1,1),
                    padding = 'same', input_shape=input_shape))
    model.add(Dropout(0.1))
    model.add(Conv2D(32,(3,3), activation='relu', strides=(1,1),
                    padding = 'same', input_shape=input_shape))
    model.add(Dropout(0.1))
    model.add(Conv2D(64,(3,3), activation='relu', strides=(1,1),
                    padding = 'same', input_shape=input_shape))
    model.add(Dropout(0.2))
    model.add(Conv2D(128,(3,3), activation='relu', strides=(1,1),
                    padding = 'same', input_shape=input_shape))


    model.add(MaxPool2D((1,1),strides=2))



    model.add(Flatten())

    model.add(Dense(128, activation='relu'))
    model.add(Dense(96, activation='relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(32, activation='tanh'))
    model.add(Dense(8, activation='softmax'))
    model.summary()
    model.compile(loss='categorical_crossentropy',
                 optimizer='adam',
                 metrics=['acc'])
    return model
model = get_conv_model()
model.load_weights('weights.best.basic_cnn.hdf5')
drumlist = ['808', 'Clap', 'Closed Hat', 'Kick', 'Open Hat', 'Snare', 'Tom',
       'Vox']
data = extract_features('DrumSamples/Chinese Clap 2.wav')
data = data.reshape(1, 128, 1, 1)

pred = np.unique(drumlist)[np.argmax(model.predict(data)[0])]
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 128, 1, 8)         80
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 128, 1, 8)         0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 128, 1, 16)        1168
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 128, 1, 16)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 128, 1, 32)        4640
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 128, 1, 32)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 128, 1, 64)        18496
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 128, 1, 64)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 128, 1, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 64, 1, 128)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               1048704
# _________________________________________________________________
# dense_7 (Dense)              (None, 96)                12384
# _________________________________________________________________
# dense_8 (Dense)              (None, 64)                6208
# _________________________________________________________________
# dense_9 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_10 (Dense)             (None, 8)                 264
# =================================================================
# Total params: 1,167,880
# Trainable params: 1,167,880
# Non-trainable params: 0
# _________________________________________________________________
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-161-bcf18df15846> in <module>
#      40        'Vox']
#      41 data = extract_features('DrumSamples/Chinese Clap 2.wav')
# ---> 42 data = data.reshape(1, 128, 1, 1)
#      43
#      44 pred = np.unique(drumlist)[np.argmax(model.predict(data)[0])]
#
# ValueError: cannot reshape array of size 52 into shape (1,128,1,1)

# %%
model.predict(x_test)[0]
# Out:
# array([1.7423079e-04, 4.1756177e-04, 3.1120231e-05, 9.9844837e-01,
#        2.3636627e-05, 2.9990822e-04, 3.2244937e-04, 2.8276432e-04],
#       dtype=float32)

# %%
drumlist = ['808', 'Clap', 'Closed Hat', 'Kick', 'Open Hat', 'Snare', 'Tom',
       'Vox']

# %%
np.unique(featuresdf.class_label)
# Out:
# array(['808', 'Clap', 'Closed Hat', 'Kick', 'Open Hat', 'Snare', 'Tom',
#        'Vox'], dtype=object)

# %%
data = data.reshape(1, 128, 1, 1)

# %%
np.unique(drumlist)[np.argmax(model.predict(data)[0])]
# Out:
# 'Clap'

# %%
np.argmax(model.predict(x_test)[0])
# Out:
# 3

# %%
# Out:
# array([[-381.98254]], dtype=float32)

# %%
# Out:
# array([[-260.58]], dtype=float32)

# %%
featuresdf.feature
# Out:
# 0       [[22.765911039513178, -5.67091478991529, -23.8...
# 1       [[23.48484416744163, 1.9868645091496475, -38.4...
# 2       [[23.48475259504359, -27.697800995478044, -47....
# 3       [[23.116899180964793, -43.01835326544213, -21....
# 4       [[12.279290752172475, -23.263314297599262, -18...
# 5       [[2.2725942237922014, -38.38069798855538, -13....
# 6       [[5.393900863268132, -36.74016214871553, -13.4...
# 7       [[16.172406211473497, -6.4603145868088525, -2....
# 8       [[22.95394760248493, -6.462339968175857, -24.1...
# 9       [[19.082039107561137, 16.291238585993895, -2.1...
# 10      [[20.65635063135986, 13.865292439026884, -5.15...
# 11      [[23.745243174517213, -38.53594273730368, -35....
# 12      [[19.112940929844495, 38.91752821082826, 29.05...
# 13      [[17.338830399428158, 21.90692885662154, 22.22...
# 14      [[17.999590413443972, 3.1372100711575888, -31....
# 15      [[19.600837386309905, 30.089218666360768, 17.1...
# 16      [[23.43682666188702, -16.945954442271994, -35....
# 17      [[4.696650946414335, -14.782923110303447, 1.07...
# 18      [[19.14710225449231, 45.907835162635756, 19.52...
# 19      [[5.430649407272429, -35.10263100356771, -10.3...
# 20      [[5.337134592784451, -33.51937648987924, -7.95...
# 21      [[24.446305678346253, -8.47725477606213, -29.0...
# 22      [[23.55106313303581, -17.006139781463084, -24....
# 23      [[-36.04365338911715, 0.0, -3.2076317224819155...
# 24      [[24.547154263426034, -67.79954679883384, -15....
# 25      [[19.87751893894399, 5.606018341811156, -24.16...
# 26      [[24.570032811619157, -36.52651208376998, -58....
# 27      [[22.784624022632237, 4.539163640352377, -17.2...
# 28      [[24.277254534377253, -14.621575594002893, -20...
# 29      [[19.826402416783733, 4.515816763080275, -17.3...
#                               ...
# 4448    [[3.13176789492203, -16.098227758599382, -9.22...
# 4449    [[19.984660304192445, 21.840187450475803, 1.17...
# 4450    [[24.811430385690784, -5.495121095930951, -26....
# 4451    [[22.323753264488737, -8.279935731243837, -6.9...
# 4452    [[15.967119128516428, -1.79881205585746, -18.9...
# 4453    [[20.76371310220898, 23.168077525590373, -0.01...
# 4454    [[-36.04365338911715, 0.0, -3.2076317224819155...
# 4455    [[22.747203144752252, -44.245591179782004, -67...
# 4456    [[19.490613363052642, 27.26851723385791, 11.39...
# 4457    [[24.256705858443368, -3.133615315628057, -63....
# 4458    [[24.821014654668684, -53.099756838706845, -45...
# 4459    [[20.699822023979728, -4.00180848696564, -27.3...
# 4460    [[17.187063850288794, 8.45625556826396, -6.317...
# 4461    [[23.241209863706672, -0.3233734057951691, -26...
# 4462    [[18.980258307778108, -4.815100820727122, -16....
# 4463    [[19.94772557348459, 25.04842459227977, 16.727...
# 4464    [[22.949667654287513, -3.2439998931953182, -17...
# 4465    [[16.146500337059752, 14.78410765110618, -12.7...
# 4466    [[21.4641800747131, 35.44899886753777, 7.83770...
# 4467    [[24.71871707109116, -48.32725178389219, -26.6...
# 4468    [[22.974874071032243, 16.41359658532777, -17.1...
# 4469    [[-36.04365338911715, 0.0, -3.2076317224819155...
# 4470    [[19.427434392370177, 28.11192170156852, 11.00...
# 4471    [[24.066551644802633, -9.903514929259547, -28....
# 4472    [[20.048402233256102, 25.079713110051944, 17.3...
# 4473    [[24.48966766943834, -35.40104170381398, -19.7...
# 4474    [[20.097246284664248, 27.588131936868713, 14.6...
# 4475    [[-36.04365338911715, 0.0, -3.2076317224819155...
# 4476    [[23.49419622846191, -51.923663528738146, -41....
# 4477    [[10.676026383292866, -28.0044411548391, -10.7...
# Name: feature, Length: 4478, dtype: object

# %%
np.array(X).shape
# Out:
# (4478,)

# %%
X = []
for i in featuresdf.feature:
    X.append(np.array(i))

# %%
np.array(X).shape
# Out:
# (4478,)

# %%
X = np.concatenate(X)

# %%
X = X.reshape()

# %%
type(np.concatenate(X))
# Out:
# numpy.ndarray

# %%
from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical
from imblearn.combine import SMOTETomek
from imblearn.under_sampling import NearMiss

# Convert features and corresponding classification labels into numpy arrays
#X = np.array(featuresdf.feature)
y = np.array(featuresdf.class_label.tolist())

# Encode the classification labels
sm = SMOTETomek(random_state = 3)
le = LabelEncoder()
yy = to_categorical(le.fit_transform(y)) 

# split the dataset 
from sklearn.model_selection import train_test_split 

#X_res, y_res = sm.fit_sample(X,yy)

x_train, x_test, y_train, y_test = train_test_split(X, yy, test_size=0.2, random_state = 42)

# %%
from keras.layers import Conv2D, MaxPool2D, Flatten, LSTM
from keras.layers import Dropout, Dense, TimeDistributed
from keras.models import Sequential
from keras.utils import to_categorical
from keras.callbacks import ModelCheckpoint
from sklearn.utils.class_weight import compute_class_weight

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Convolution2D, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.optimizers import Adam
from keras.utils import np_utils
from sklearn import metrics

# %%
def get_conv_model():
    model = Sequential()
    model.add(Conv2D(8,(3,3), activation='relu', strides=(1,1),
                    padding = 'same', input_shape=input_shape))
    model.add(Dropout(0.1))
    model.add(Conv2D(16,(3,3), activation='relu', strides=(1,1),
                    padding = 'same', input_shape=input_shape))
    model.add(Dropout(0.1))
    model.add(Conv2D(32,(3,3), activation='relu', strides=(1,1),
                    padding = 'same', input_shape=input_shape))
    model.add(Dropout(0.1))
    model.add(Conv2D(64,(3,3), activation='relu', strides=(1,1),
                    padding = 'same', input_shape=input_shape))
    model.add(Dropout(0.2))
    model.add(Conv2D(128,(3,3), activation='relu', strides=(1,1),
                    padding = 'same', input_shape=input_shape))


    model.add(MaxPool2D((1,1),strides=2))



    model.add(Flatten())

    model.add(Dense(128, activation='relu'))
    model.add(Dense(96, activation='relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(32, activation='tanh'))
    model.add(Dense(8, activation='softmax'))
    model.summary()
    model.compile(loss='categorical_crossentropy',
                 optimizer='adam',
                 metrics=['acc'])
    return model

# %%
from keras.callbacks import ModelCheckpoint

# %%
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2],1)
# Out:
# (3582,)

# %%
checkpointer = ModelCheckpoint(filepath='weights.best.basic_cnn2.hdf5', 
                               verbose=1, save_best_only=True)
x_train = x_train.reshape(x_train.shape[0], 1, 13,1)
x_test = x_test.reshape(x_test.shape[0], 1, 13,1)
input_shape = (1, 13,1)
model = get_conv_model()
model.fit(x_train, y_train, batch_size=677, epochs=100, validation_data=(x_test, y_test), callbacks=[checkpointer], verbose=1)
# Out:
# W1121 15:47:42.251515 4672710080 deprecation.py:323] From /Users/robertfustero/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_11 (Conv2D)           (None, 1, 13, 8)          80
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 1, 13, 8)          0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 1, 13, 16)         1168
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 1, 13, 16)         0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 1, 13, 32)         4640
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 1, 13, 32)         0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 1, 13, 64)         18496
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 1, 13, 64)         0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 1, 13, 128)        73856
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 7, 128)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 896)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 128)               114816
# _________________________________________________________________
# dense_12 (Dense)             (None, 96)                12384
# _________________________________________________________________
# dense_13 (Dense)             (None, 64)                6208
# _________________________________________________________________
# dense_14 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_15 (Dense)             (None, 8)                 264
# =================================================================
# Total params: 233,992
# Trainable params: 233,992
# Non-trainable params: 0
# _________________________________________________________________
# Train on 3582 samples, validate on 896 samples
# Epoch 1/100
# 3582/3582 [==============================] - 4s 1ms/step - loss: 2.0042 - acc: 0.2647 - val_loss: 1.8375 - val_acc: 0.2813
#
# Epoch 00001: val_loss improved from inf to 1.83754, saving model to weights.best.basic_cnn2.hdf5
# Epoch 2/100
# 3582/3582 [==============================] - 1s 207us/step - loss: 1.7658 - acc: 0.3571 - val_loss: 1.5898 - val_acc: 0.3984
#
# Epoch 00002: val_loss improved from 1.83754 to 1.58983, saving model to weights.best.basic_cnn2.hdf5
# Epoch 3/100
# 3582/3582 [==============================] - 1s 206us/step - loss: 1.5344 - acc: 0.4400 - val_loss: 1.3910 - val_acc: 0.4676
#
# Epoch 00003: val_loss improved from 1.58983 to 1.39098, saving model to weights.best.basic_cnn2.hdf5
# Epoch 4/100
# 3582/3582 [==============================] - 1s 204us/step - loss: 1.3993 - acc: 0.4785 - val_loss: 1.3019 - val_acc: 0.5000
#
# Epoch 00004: val_loss improved from 1.39098 to 1.30188, saving model to weights.best.basic_cnn2.hdf5
# Epoch 5/100
# 3582/3582 [==============================] - 1s 256us/step - loss: 1.3119 - acc: 0.5039 - val_loss: 1.2254 - val_acc: 0.5156
#
# Epoch 00005: val_loss improved from 1.30188 to 1.22536, saving model to weights.best.basic_cnn2.hdf5
# Epoch 6/100
# 3582/3582 [==============================] - 1s 242us/step - loss: 1.2553 - acc: 0.5262 - val_loss: 1.1806 - val_acc: 0.5335
#
# Epoch 00006: val_loss improved from 1.22536 to 1.18057, saving model to weights.best.basic_cnn2.hdf5
# Epoch 7/100
# 3582/3582 [==============================] - 1s 202us/step - loss: 1.2130 - acc: 0.5469 - val_loss: 1.1700 - val_acc: 0.5424
#
# Epoch 00007: val_loss improved from 1.18057 to 1.17000, saving model to weights.best.basic_cnn2.hdf5
# Epoch 8/100
# 3582/3582 [==============================] - 1s 202us/step - loss: 1.1965 - acc: 0.5491 - val_loss: 1.1323 - val_acc: 0.5536
#
# Epoch 00008: val_loss improved from 1.17000 to 1.13228, saving model to weights.best.basic_cnn2.hdf5
# Epoch 9/100
# 3582/3582 [==============================] - 1s 235us/step - loss: 1.1617 - acc: 0.5687 - val_loss: 1.0968 - val_acc: 0.5759
#
# Epoch 00009: val_loss improved from 1.13228 to 1.09676, saving model to weights.best.basic_cnn2.hdf5
# Epoch 10/100
# 3582/3582 [==============================] - 1s 212us/step - loss: 1.1293 - acc: 0.5717 - val_loss: 1.0768 - val_acc: 0.5859
#
# Epoch 00010: val_loss improved from 1.09676 to 1.07684, saving model to weights.best.basic_cnn2.hdf5
# Epoch 11/100
# 3582/3582 [==============================] - 1s 211us/step - loss: 1.1003 - acc: 0.5902 - val_loss: 1.0719 - val_acc: 0.5815
#
# Epoch 00011: val_loss improved from 1.07684 to 1.07194, saving model to weights.best.basic_cnn2.hdf5
# Epoch 12/100
# 3582/3582 [==============================] - 1s 210us/step - loss: 1.0894 - acc: 0.5949 - val_loss: 1.0494 - val_acc: 0.5904
#
# Epoch 00012: val_loss improved from 1.07194 to 1.04935, saving model to weights.best.basic_cnn2.hdf5
# Epoch 13/100
# 3582/3582 [==============================] - 1s 220us/step - loss: 1.0723 - acc: 0.5999 - val_loss: 1.0307 - val_acc: 0.5949
#
# Epoch 00013: val_loss improved from 1.04935 to 1.03072, saving model to weights.best.basic_cnn2.hdf5
# Epoch 14/100
# 3582/3582 [==============================] - 1s 243us/step - loss: 1.0446 - acc: 0.6159 - val_loss: 1.0207 - val_acc: 0.6038
#
# Epoch 00014: val_loss improved from 1.03072 to 1.02071, saving model to weights.best.basic_cnn2.hdf5
# Epoch 15/100
# 3582/3582 [==============================] - 1s 236us/step - loss: 1.0400 - acc: 0.6139 - val_loss: 1.0088 - val_acc: 0.5971
#
# Epoch 00015: val_loss improved from 1.02071 to 1.00881, saving model to weights.best.basic_cnn2.hdf5
# Epoch 16/100
# 3582/3582 [==============================] - 1s 236us/step - loss: 1.0229 - acc: 0.6122 - val_loss: 0.9888 - val_acc: 0.6138
#
# Epoch 00016: val_loss improved from 1.00881 to 0.98876, saving model to weights.best.basic_cnn2.hdf5
# Epoch 17/100
# 3582/3582 [==============================] - 1s 239us/step - loss: 1.0200 - acc: 0.6125 - val_loss: 0.9782 - val_acc: 0.6306
#
# Epoch 00017: val_loss improved from 0.98876 to 0.97817, saving model to weights.best.basic_cnn2.hdf5
# Epoch 18/100
# 3582/3582 [==============================] - 1s 253us/step - loss: 1.0094 - acc: 0.6131 - val_loss: 0.9849 - val_acc: 0.6239
#
# Epoch 00018: val_loss did not improve from 0.97817
# Epoch 19/100
# 3582/3582 [==============================] - 1s 256us/step - loss: 0.9973 - acc: 0.6220 - val_loss: 0.9659 - val_acc: 0.6194
#
# Epoch 00019: val_loss improved from 0.97817 to 0.96592, saving model to weights.best.basic_cnn2.hdf5
# Epoch 20/100
# 3582/3582 [==============================] - 1s 211us/step - loss: 0.9853 - acc: 0.6279 - val_loss: 0.9641 - val_acc: 0.6172
#
# Epoch 00020: val_loss improved from 0.96592 to 0.96406, saving model to weights.best.basic_cnn2.hdf5
# Epoch 21/100
# 3582/3582 [==============================] - 1s 204us/step - loss: 0.9786 - acc: 0.6365 - val_loss: 0.9630 - val_acc: 0.6239
#
# Epoch 00021: val_loss improved from 0.96406 to 0.96305, saving model to weights.best.basic_cnn2.hdf5
# Epoch 22/100
# 3582/3582 [==============================] - 1s 203us/step - loss: 0.9656 - acc: 0.6318 - val_loss: 0.9449 - val_acc: 0.6362
#
# Epoch 00022: val_loss improved from 0.96305 to 0.94494, saving model to weights.best.basic_cnn2.hdf5
# Epoch 23/100
# 3582/3582 [==============================] - 1s 197us/step - loss: 0.9534 - acc: 0.6371 - val_loss: 0.9332 - val_acc: 0.6317
#
# Epoch 00023: val_loss improved from 0.94494 to 0.93319, saving model to weights.best.basic_cnn2.hdf5
# Epoch 24/100
# 3582/3582 [==============================] - 1s 208us/step - loss: 0.9509 - acc: 0.6237 - val_loss: 0.9356 - val_acc: 0.6362
#
# Epoch 00024: val_loss did not improve from 0.93319
# Epoch 25/100
# 3582/3582 [==============================] - 1s 214us/step - loss: 0.9449 - acc: 0.6337 - val_loss: 0.9346 - val_acc: 0.6339
#
# Epoch 00025: val_loss did not improve from 0.93319
# Epoch 26/100
# 3582/3582 [==============================] - 1s 234us/step - loss: 0.9500 - acc: 0.6371 - val_loss: 0.9274 - val_acc: 0.6373
#
# Epoch 00026: val_loss improved from 0.93319 to 0.92737, saving model to weights.best.basic_cnn2.hdf5
# Epoch 27/100
# 3582/3582 [==============================] - 1s 216us/step - loss: 0.9369 - acc: 0.6396 - val_loss: 0.9400 - val_acc: 0.6295
#
# Epoch 00027: val_loss did not improve from 0.92737
# Epoch 28/100
# 3582/3582 [==============================] - 1s 233us/step - loss: 0.9422 - acc: 0.6432 - val_loss: 0.9329 - val_acc: 0.6217
#
# Epoch 00028: val_loss did not improve from 0.92737
# Epoch 29/100
# 3582/3582 [==============================] - 1s 210us/step - loss: 0.9254 - acc: 0.6510 - val_loss: 0.9160 - val_acc: 0.6462
#
# Epoch 00029: val_loss improved from 0.92737 to 0.91604, saving model to weights.best.basic_cnn2.hdf5
# Epoch 30/100
# 3582/3582 [==============================] - 1s 207us/step - loss: 0.9255 - acc: 0.6435 - val_loss: 0.9249 - val_acc: 0.6183
#
# Epoch 00030: val_loss did not improve from 0.91604
# Epoch 31/100
# 3582/3582 [==============================] - 1s 212us/step - loss: 0.9166 - acc: 0.6449 - val_loss: 0.8970 - val_acc: 0.6574
#
# Epoch 00031: val_loss improved from 0.91604 to 0.89699, saving model to weights.best.basic_cnn2.hdf5
# Epoch 32/100
# 3582/3582 [==============================] - 1s 211us/step - loss: 0.9174 - acc: 0.6519 - val_loss: 0.9318 - val_acc: 0.6350
#
# Epoch 00032: val_loss did not improve from 0.89699
# Epoch 33/100
# 3582/3582 [==============================] - 1s 215us/step - loss: 0.9374 - acc: 0.6360 - val_loss: 0.9216 - val_acc: 0.6194
#
# Epoch 00033: val_loss did not improve from 0.89699
# Epoch 34/100
# 3582/3582 [==============================] - 1s 202us/step - loss: 0.9160 - acc: 0.6513 - val_loss: 0.9172 - val_acc: 0.6317
#
# Epoch 00034: val_loss did not improve from 0.89699
# Epoch 35/100
# 3582/3582 [==============================] - 1s 208us/step - loss: 0.9172 - acc: 0.6513 - val_loss: 0.9063 - val_acc: 0.6417
#
# Epoch 00035: val_loss did not improve from 0.89699
# Epoch 36/100
# 3582/3582 [==============================] - 1s 203us/step - loss: 0.8967 - acc: 0.6555 - val_loss: 0.8886 - val_acc: 0.6518
#
# Epoch 00036: val_loss improved from 0.89699 to 0.88863, saving model to weights.best.basic_cnn2.hdf5
# Epoch 37/100
# 3582/3582 [==============================] - 1s 202us/step - loss: 0.8891 - acc: 0.6516 - val_loss: 0.9009 - val_acc: 0.6484
#
# Epoch 00037: val_loss did not improve from 0.88863
# Epoch 38/100
# 3582/3582 [==============================] - 1s 197us/step - loss: 0.9013 - acc: 0.6441 - val_loss: 0.9029 - val_acc: 0.6317
#
# Epoch 00038: val_loss did not improve from 0.88863
# Epoch 39/100
# 3582/3582 [==============================] - 1s 203us/step - loss: 0.8949 - acc: 0.6454 - val_loss: 0.8885 - val_acc: 0.6484
#
# Epoch 00039: val_loss improved from 0.88863 to 0.88851, saving model to weights.best.basic_cnn2.hdf5
# Epoch 40/100
# 3582/3582 [==============================] - 1s 202us/step - loss: 0.8894 - acc: 0.6519 - val_loss: 0.8978 - val_acc: 0.6574
#
# Epoch 00040: val_loss did not improve from 0.88851
# Epoch 41/100
# 3582/3582 [==============================] - 1s 202us/step - loss: 0.8736 - acc: 0.6647 - val_loss: 0.8884 - val_acc: 0.6529
#
# Epoch 00041: val_loss improved from 0.88851 to 0.88842, saving model to weights.best.basic_cnn2.hdf5
# Epoch 42/100
# 3582/3582 [==============================] - 1s 212us/step - loss: 0.8611 - acc: 0.6700 - val_loss: 0.8882 - val_acc: 0.6462
#
# Epoch 00042: val_loss improved from 0.88842 to 0.88819, saving model to weights.best.basic_cnn2.hdf5
# Epoch 43/100
# 3582/3582 [==============================] - 1s 199us/step - loss: 0.8725 - acc: 0.6608 - val_loss: 0.8984 - val_acc: 0.6462
#
# Epoch 00043: val_loss did not improve from 0.88819
# Epoch 44/100
# 3582/3582 [==============================] - 1s 201us/step - loss: 0.8645 - acc: 0.6672 - val_loss: 0.8805 - val_acc: 0.6607
#
# Epoch 00044: val_loss improved from 0.88819 to 0.88053, saving model to weights.best.basic_cnn2.hdf5
# Epoch 45/100
# 3582/3582 [==============================] - 1s 211us/step - loss: 0.8551 - acc: 0.6683 - val_loss: 0.8874 - val_acc: 0.6406
#
# Epoch 00045: val_loss did not improve from 0.88053
# Epoch 46/100
# 3582/3582 [==============================] - 1s 207us/step - loss: 0.8625 - acc: 0.6555 - val_loss: 0.8811 - val_acc: 0.6518
#
# Epoch 00046: val_loss did not improve from 0.88053
# Epoch 47/100
# 3582/3582 [==============================] - 1s 222us/step - loss: 0.8590 - acc: 0.6625 - val_loss: 0.8743 - val_acc: 0.6462
#
# Epoch 00047: val_loss improved from 0.88053 to 0.87426, saving model to weights.best.basic_cnn2.hdf5
# Epoch 48/100
# 3582/3582 [==============================] - 1s 210us/step - loss: 0.8569 - acc: 0.6667 - val_loss: 0.8838 - val_acc: 0.6462
#
# Epoch 00048: val_loss did not improve from 0.87426
# Epoch 49/100
# 3582/3582 [==============================] - 1s 223us/step - loss: 0.8478 - acc: 0.6731 - val_loss: 0.8887 - val_acc: 0.6484
#
# Epoch 00049: val_loss did not improve from 0.87426
# Epoch 50/100
# 3582/3582 [==============================] - 1s 198us/step - loss: 0.8598 - acc: 0.6667 - val_loss: 0.8694 - val_acc: 0.6563
#
# Epoch 00050: val_loss improved from 0.87426 to 0.86939, saving model to weights.best.basic_cnn2.hdf5
# Epoch 51/100
# 3582/3582 [==============================] - 1s 231us/step - loss: 0.8343 - acc: 0.6703 - val_loss: 0.8900 - val_acc: 0.6540
#
# Epoch 00051: val_loss did not improve from 0.86939
# Epoch 52/100
# 3582/3582 [==============================] - 1s 215us/step - loss: 0.8379 - acc: 0.6720 - val_loss: 0.8638 - val_acc: 0.6641
#
# Epoch 00052: val_loss improved from 0.86939 to 0.86375, saving model to weights.best.basic_cnn2.hdf5
# Epoch 53/100
# 3582/3582 [==============================] - 1s 197us/step - loss: 0.8296 - acc: 0.6762 - val_loss: 0.8747 - val_acc: 0.6618
#
# Epoch 00053: val_loss did not improve from 0.86375
# Epoch 54/100
# 3582/3582 [==============================] - 1s 202us/step - loss: 0.8252 - acc: 0.6787 - val_loss: 0.8629 - val_acc: 0.6652
#
# Epoch 00054: val_loss improved from 0.86375 to 0.86293, saving model to weights.best.basic_cnn2.hdf5
# Epoch 55/100
# 3582/3582 [==============================] - 1s 224us/step - loss: 0.8200 - acc: 0.6781 - val_loss: 0.8692 - val_acc: 0.6507
#
# Epoch 00055: val_loss did not improve from 0.86293
# Epoch 56/100
# 3582/3582 [==============================] - 1s 208us/step - loss: 0.8191 - acc: 0.6803 - val_loss: 0.8631 - val_acc: 0.6551
#
# Epoch 00056: val_loss did not improve from 0.86293
# Epoch 57/100
# 3582/3582 [==============================] - 1s 204us/step - loss: 0.8120 - acc: 0.6778 - val_loss: 0.8765 - val_acc: 0.6641
#
# Epoch 00057: val_loss did not improve from 0.86293
# Epoch 58/100
# 3582/3582 [==============================] - 1s 210us/step - loss: 0.8304 - acc: 0.6798 - val_loss: 0.8843 - val_acc: 0.6596
#
# Epoch 00058: val_loss did not improve from 0.86293
# Epoch 59/100
# 3582/3582 [==============================] - 1s 202us/step - loss: 0.8358 - acc: 0.6720 - val_loss: 0.8693 - val_acc: 0.6663
#
# Epoch 00059: val_loss did not improve from 0.86293
# Epoch 60/100
# 3582/3582 [==============================] - 1s 210us/step - loss: 0.8284 - acc: 0.6764 - val_loss: 0.8726 - val_acc: 0.6473
#
# Epoch 00060: val_loss did not improve from 0.86293
# Epoch 61/100
# 3582/3582 [==============================] - 1s 218us/step - loss: 0.8027 - acc: 0.6790 - val_loss: 0.8607 - val_acc: 0.6629
#
# Epoch 00061: val_loss improved from 0.86293 to 0.86065, saving model to weights.best.basic_cnn2.hdf5
# Epoch 62/100
# 3582/3582 [==============================] - 1s 205us/step - loss: 0.7989 - acc: 0.6817 - val_loss: 0.8613 - val_acc: 0.6618
#
# Epoch 00062: val_loss did not improve from 0.86065
# Epoch 63/100
# 3582/3582 [==============================] - 1s 206us/step - loss: 0.7769 - acc: 0.6932 - val_loss: 0.8459 - val_acc: 0.6730
#
# Epoch 00063: val_loss improved from 0.86065 to 0.84594, saving model to weights.best.basic_cnn2.hdf5
# Epoch 64/100
# 3582/3582 [==============================] - 1s 210us/step - loss: 0.7837 - acc: 0.6843 - val_loss: 0.8618 - val_acc: 0.6629
# Epoch 00064: val_loss did not improve from 0.84594
# Epoch 65/100
# 3582/3582 [==============================] - 1s 198us/step - loss: 0.7928 - acc: 0.6918 - val_loss: 0.8634 - val_acc: 0.6596
#
# Epoch 00065: val_loss did not improve from 0.84594
# Epoch 66/100
# 3582/3582 [==============================] - 1s 208us/step - loss: 0.7735 - acc: 0.6929 - val_loss: 0.8644 - val_acc: 0.6719
#
# Epoch 00066: val_loss did not improve from 0.84594
# Epoch 67/100
# 3582/3582 [==============================] - 1s 197us/step - loss: 0.7870 - acc: 0.6884 - val_loss: 0.8578 - val_acc: 0.6607
#
# Epoch 00067: val_loss did not improve from 0.84594
# Epoch 68/100
# 3582/3582 [==============================] - 1s 204us/step - loss: 0.7800 - acc: 0.6957 - val_loss: 0.8716 - val_acc: 0.6652
#
# Epoch 00068: val_loss did not improve from 0.84594
# Epoch 69/100
# 3582/3582 [==============================] - 1s 200us/step - loss: 0.7837 - acc: 0.6918 - val_loss: 0.8698 - val_acc: 0.6607
#
# Epoch 00069: val_loss did not improve from 0.84594
# Epoch 70/100
# 3582/3582 [==============================] - 1s 204us/step - loss: 0.7825 - acc: 0.7010 - val_loss: 0.8569 - val_acc: 0.6719
#
# Epoch 00070: val_loss did not improve from 0.84594
# Epoch 71/100
# 3582/3582 [==============================] - 1s 197us/step - loss: 0.7812 - acc: 0.6907 - val_loss: 0.8578 - val_acc: 0.6641
#
# Epoch 00071: val_loss did not improve from 0.84594
# Epoch 72/100
# 3582/3582 [==============================] - 1s 199us/step - loss: 0.7695 - acc: 0.6991 - val_loss: 0.8537 - val_acc: 0.6652
#
# Epoch 00072: val_loss did not improve from 0.84594
# Epoch 73/100
# 3582/3582 [==============================] - 1s 202us/step - loss: 0.7677 - acc: 0.7035 - val_loss: 0.8509 - val_acc: 0.6730
#
# Epoch 00073: val_loss did not improve from 0.84594
# Epoch 74/100
# 3582/3582 [==============================] - 1s 206us/step - loss: 0.7566 - acc: 0.7055 - val_loss: 0.8574 - val_acc: 0.6652
#
# Epoch 00074: val_loss did not improve from 0.84594
# Epoch 75/100
# 3582/3582 [==============================] - 1s 201us/step - loss: 0.7487 - acc: 0.7088 - val_loss: 0.8543 - val_acc: 0.6529
#
# Epoch 00075: val_loss did not improve from 0.84594
# Epoch 76/100
# 3582/3582 [==============================] - 1s 225us/step - loss: 0.7480 - acc: 0.7116 - val_loss: 0.8570 - val_acc: 0.6585
#
# Epoch 00076: val_loss did not improve from 0.84594
# Epoch 77/100
# 3582/3582 [==============================] - 1s 212us/step - loss: 0.7471 - acc: 0.7094 - val_loss: 0.8616 - val_acc: 0.6641
#
# Epoch 00077: val_loss did not improve from 0.84594
# Epoch 78/100
# 3582/3582 [==============================] - 1s 237us/step - loss: 0.7431 - acc: 0.7010 - val_loss: 0.8479 - val_acc: 0.6730
#
# Epoch 00078: val_loss did not improve from 0.84594
# Epoch 79/100
# 3582/3582 [==============================] - 1s 214us/step - loss: 0.7486 - acc: 0.7041 - val_loss: 0.8737 - val_acc: 0.6507
#
# Epoch 00079: val_loss did not improve from 0.84594
# Epoch 80/100
# 3582/3582 [==============================] - 1s 200us/step - loss: 0.7317 - acc: 0.7119 - val_loss: 0.8653 - val_acc: 0.6641
#
# Epoch 00080: val_loss did not improve from 0.84594
# Epoch 81/100
# 3582/3582 [==============================] - 1s 237us/step - loss: 0.7373 - acc: 0.7094 - val_loss: 0.8736 - val_acc: 0.6618
#
# Epoch 00081: val_loss did not improve from 0.84594
# Epoch 82/100
# 3582/3582 [==============================] - 1s 218us/step - loss: 0.7280 - acc: 0.7217 - val_loss: 0.8882 - val_acc: 0.6462
#
# Epoch 00082: val_loss did not improve from 0.84594
# Epoch 83/100
# 3582/3582 [==============================] - 1s 208us/step - loss: 0.7509 - acc: 0.7018 - val_loss: 0.8719 - val_acc: 0.6752
#
# Epoch 00083: val_loss did not improve from 0.84594
# Epoch 84/100
# 3582/3582 [==============================] - 1s 197us/step - loss: 0.7481 - acc: 0.7046 - val_loss: 0.8707 - val_acc: 0.6596
#
# Epoch 00084: val_loss did not improve from 0.84594
# Epoch 85/100
# 3582/3582 [==============================] - 1s 204us/step - loss: 0.7385 - acc: 0.7071 - val_loss: 0.8599 - val_acc: 0.6763
#
# Epoch 00085: val_loss did not improve from 0.84594
# Epoch 86/100
# 3582/3582 [==============================] - 1s 267us/step - loss: 0.7313 - acc: 0.7097 - val_loss: 0.8594 - val_acc: 0.6641
#
# Epoch 00086: val_loss did not improve from 0.84594
# Epoch 87/100
# 3582/3582 [==============================] - 1s 266us/step - loss: 0.7245 - acc: 0.7169 - val_loss: 0.8691 - val_acc: 0.6752
#
# Epoch 00087: val_loss did not improve from 0.84594
# Epoch 88/100
# 3582/3582 [==============================] - 1s 266us/step - loss: 0.7289 - acc: 0.7158 - val_loss: 0.8704 - val_acc: 0.6752
#
# Epoch 00088: val_loss did not improve from 0.84594
# Epoch 89/100
# 3582/3582 [==============================] - 1s 246us/step - loss: 0.7342 - acc: 0.7133 - val_loss: 0.8824 - val_acc: 0.6607
#
# Epoch 00089: val_loss did not improve from 0.84594
# Epoch 90/100
# 3582/3582 [==============================] - 1s 250us/step - loss: 0.7178 - acc: 0.7152 - val_loss: 0.8600 - val_acc: 0.6607
#
# Epoch 00090: val_loss did not improve from 0.84594
# Epoch 91/100
# 3582/3582 [==============================] - 1s 223us/step - loss: 0.7116 - acc: 0.7247 - val_loss: 0.8708 - val_acc: 0.6518
#
# Epoch 00091: val_loss did not improve from 0.84594
# Epoch 92/100
# 3582/3582 [==============================] - 1s 212us/step - loss: 0.6943 - acc: 0.7233 - val_loss: 0.8655 - val_acc: 0.6685
#
# Epoch 00092: val_loss did not improve from 0.84594
# Epoch 93/100
# 3582/3582 [==============================] - 1s 203us/step - loss: 0.7036 - acc: 0.7233 - val_loss: 0.8593 - val_acc: 0.6775
#
# Epoch 00093: val_loss did not improve from 0.84594
# Epoch 94/100
# 3582/3582 [==============================] - 1s 197us/step - loss: 0.7018 - acc: 0.7217 - val_loss: 0.8622 - val_acc: 0.6763
#
# Epoch 00094: val_loss did not improve from 0.84594
# Epoch 95/100
# 3582/3582 [==============================] - 1s 198us/step - loss: 0.6973 - acc: 0.7236 - val_loss: 0.8895 - val_acc: 0.6507
#
# Epoch 00095: val_loss did not improve from 0.84594
# Epoch 96/100
# 3582/3582 [==============================] - 1s 218us/step - loss: 0.6887 - acc: 0.7339 - val_loss: 0.8993 - val_acc: 0.6652
#
# Epoch 00096: val_loss did not improve from 0.84594
# Epoch 97/100
# 3582/3582 [==============================] - 1s 271us/step - loss: 0.7013 - acc: 0.7197 - val_loss: 0.8801 - val_acc: 0.6551
#
# Epoch 00097: val_loss did not improve from 0.84594
# Epoch 98/100
# 3582/3582 [==============================] - 1s 282us/step - loss: 0.6844 - acc: 0.7351 - val_loss: 0.8731 - val_acc: 0.6652
#
# Epoch 00098: val_loss did not improve from 0.84594
# Epoch 99/100
# 3582/3582 [==============================] - 1s 237us/step - loss: 0.6787 - acc: 0.7367 - val_loss: 0.8898 - val_acc: 0.6462
#
# Epoch 00099: val_loss did not improve from 0.84594
# Epoch 100/100
# 3582/3582 [==============================] - 1s 252us/step - loss: 0.6811 - acc: 0.7292 - val_loss: 0.9029 - val_acc: 0.6462
#
# Epoch 00100: val_loss did not improve from 0.84594

# %%
librosa.display.specshow(mfccs, sr=fs, x_axis='time')

# %%
from sklearn.preprocessing import StandardScaler

# %%
checkpointer = ModelCheckpoint(filepath='weights.best.basic_cnn.hdf5', 
                               verbose=1, save_best_only=True)
x_train = x_train.reshape(x_train.shape[0], 128, 1, 1)
x_test = x_test.reshape(x_test.shape[0], 128, 1, 1)
input_shape = (128, 1, 1)
model = get_conv_model()
#model.fit(x_train, y_train, batch_size=677, epochs=100, validation_data=(x_test, y_test), callbacks=[checkpointer], verbose=1)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1120 19:46:47.446316 4672710080 deprecation_wrapper.py:119] From /Users/robertfustero/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W1120 19:46:47.476698 4672710080 deprecation_wrapper.py:119] From /Users/robertfustero/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W1120 19:46:47.479392 4672710080 deprecation_wrapper.py:119] From /Users/robertfustero/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W1120 19:46:47.500764 4672710080 deprecation_wrapper.py:119] From /Users/robertfustero/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# W1120 19:46:47.509730 4672710080 deprecation.py:506] From /Users/robertfustero/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W1120 19:46:47.658309 4672710080 deprecation_wrapper.py:119] From /Users/robertfustero/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W1120 19:46:47.722728 4672710080 deprecation_wrapper.py:119] From /Users/robertfustero/anaconda3/lib/python3.7/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W1120 19:46:47.741893 4672710080 deprecation_wrapper.py:119] From /Users/robertfustero/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3295: The name tf.log is deprecated. Please use tf.math.log instead.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 128, 1, 8)         80
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128, 1, 8)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 128, 1, 16)        1168
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128, 1, 16)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 128, 1, 32)        4640
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128, 1, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 128, 1, 64)        18496
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 128, 1, 64)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 128, 1, 128)       73856
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 1, 128)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               1048704
# _________________________________________________________________
# dense_2 (Dense)              (None, 96)                12384
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                6208
# _________________________________________________________________
# dense_4 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_5 (Dense)              (None, 8)                 264
# =================================================================
# Total params: 1,167,880
# Trainable params: 1,167,880
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Loads the weights
model.load_weights('weights.best.basic_cnn.hdf5')

# Re-evaluate the model
loss,acc = model.evaluate(x_test,  y_test, verbose=2)
print("Restored model, accuracy: {:5.2f}%".format(100*acc))
# Out:
# Restored model, accuracy: 97.54%

# %%
def build_predictions(audio_dir):
    y_true = []
    y_pred = []
    fn_prob = {}
    
    print('Extracting features from audio')
    for fn in tqdm(os.listdir(audio_dir)):
        rate, wav = wavfile.read(os.path.join(audio_dir, fn))
        label = fn2class[fn]
        c = classes.index(label)
        y_prob = []
        
        for i in range(0, wav.shape[0]-config.step, config.step):
            sample = wav[i:i+config.step]
            x = mfcc(sample, rate, numcep=config.nfeat,
                    nfilt=config.nfilt, nfft=config.nfft)
            x = (x - config.min)/ (config.max - config.min)
            
            if config.mode =='conv':
                x = x.reshape(1,x.shape[0], x.shape[1], 1)
            elif config.mode == 'time':
                x = np.expand_dims(x, axis=0)
            y_hat = model.predict(x)
            y_prob.append(y_hat)
            y_pred.append(np.argmax(y_hat))
            y_true.append(c)
        
        fn_prob[fn] = np.mean(y_prob, axis=0).flatten()
        
    return y_true, y_pred, fn_prob
            
df = pd.read_csv('Drum Categories.csv')
classes = list(np.unique(df.category))
fn2class = dict(zip(df.fname, df.category))
#p_path = os.path.join('pickles','conv.p')

#with open(p_path, 'rb') as handle:
#    config = pickle.load(handle)
    
#model = load_model('Audio_Classification.h5')

y_true, y_pred, fn_prob = build_predictions('DrumSamples')
acc_score = accuracy_score(y_true=y_true, y_pred=y_pred)
y_probs = []
for i, row in df.iterrows():
    y_prob = fn_prob[row.fname]
    y_probs.append(y_prob)
    for c, p in zip(classes, y_prob):
        df.at[i,c] = p
        
y_pred = [classes[np.argmax(y)] for y in y_probs]
df['y_pred'] = y_pred

df.to_csv('predictions.csv')

# %%
from sklearn.metrics import f1_score

# %%
from sklearn.metrics import accuracy_score

# %%
y_true = []
y_pred = []
for x in range(len(x_test)):
    y_true.append(np.argmax(y_test[x]))
    y_pred.append(np.argmax(model.predict(x_test)[x]))

# %%
len(y_test)

# %%
np.argmax(y_test[2])
# Out:
# 5

# %%
y_true

# %%
y_pred

# %%
accuracy_score(y_true, y_pred)

# %%
from tqdm import tqdm
from scipy.io import wavfile
from python_speech_features import mfcc, logfbank

# %%
class Config:
    def __init__(self, mode = 'conv', nfilt=26, nfeat=20, nfft=2400, rate=16000, min=min, max=max):
        self.mode = mode
        self.nfilt = nfilt
        self.nfeat = nfeat
        self.nfft = nfft
        self.rate = rate
        self.step = int(rate/29)
        self.min = min
        self.max = max

# %%
config = Config(mode='conv')

# %%
np.argmax(y_train[0])

# %%
np.argmax(model.predict(x_test)[0])

# %%
X2 = X.reshape(X.shape[0], 2, 64, 1)

# %%
model.evaluate(X2,yy)
# Out:
# 3462/3462 [==============================] - 1s 387us/step
# [0.22051872000537256, 0.924032351207623]
